# %% [markdown]
# <h1 align="center", style="color:green">Matplotlib Tutorial: Bar Chart</h1>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h3>Simple bar chart showing revenues of major US companies</h3>

# %%
company=['WMT','AMZN','MSFT','FB']
revenue=[485,136,89,27]

# %%
ypos = np.arange(len(company))

# %%
plt.bar(ypos,revenue, label="Revenue")

plt.xticks(ypos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Stocks Comparison')
plt.legend()

# %% [markdown]
# <h3>Multiple Bars showing revenue and profit of major US companies</h3>

# %%
profit=[112,2,34,12]

# %%
plt.bar(ypos-0.2,revenue, width=0.4, label="Revenue")
plt.bar(ypos+0.2,profit, width=0.4,label="Profit")

plt.xticks(ypos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Stocks Comparison')
plt.legend()

# %% [markdown]
# <h3>Horizontal bar chart using barh function<h3>

# %%
plt.barh(ypos,revenue, label="Revenue")

plt.yticks(ypos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Stocks Comparison')
plt.legend()
